# %% [raw]
# -------------------------------------------------------IMDB MOVIE ANALYSIS------------------------------------------------------------------------------

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\Ind\projects\Career fair project\IMDB_Movies.csv")

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df.shape
# Out:
# (5043, 28)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %%
df['num_critic_for_reviews']=df['num_critic_for_reviews'].astype(int)
df['duration']=df['duration'].astype(int)
df['director_facebook_likes']=df['director_facebook_likes'].astype(int)
df['actor_3_facebook_likes']=df['actor_3_facebook_likes'].astype(int)
df['actor_1_facebook_likes']=df['actor_1_facebook_likes'].astype(int)
df['gross']=df['gross'].astype(int)
df['budget']=df['budget'].astype(int)
df['title_year']=df['title_year'].astype(int)
df['actor_2_facebook_likes']=df['actor_2_facebook_likes'].astype(int)
df['movie_facebook_likes']=df['movie_facebook_likes'].astype(int)

# %%
df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             3755.000000  3755.000000              3755.000000
# mean               167.392277   110.260186               807.463648
# std                123.465521    22.649332              3068.570417
# min                  2.000000    37.000000                 0.000000
# 25%                 77.000000    96.000000                11.000000
# 50%                139.000000   106.000000                64.000000
# 75%                224.000000   120.000000               235.000000
# max                813.000000   330.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             3755.000000             3755.000000  3.755000e+03
# mean               771.484953             7753.390146  5.262614e+07
# std               1894.460316            15520.897163  7.032249e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
df.head(2)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                     723       178
# 1  Color  Gore Verbinski                     302       169
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                        0                     855  Joel David Moore
# 1                      563                    1000     Orlando Bloom
#
#    actor_1_facebook_likes      gross                           genres  ...  \
# 0                    1000  760505847  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                   40000  309404152         Action|Adventure|Fantasy  ...
#
#   num_user_for_reviews language  country  content_rating     budget  \
# 0                 3054  English      USA           PG-13  237000000
# 1                 1238  English      USA           PG-13  300000000
#
#    title_year actor_2_facebook_likes imdb_score aspect_ratio  \
# 0        2009                    936        7.9         1.78
# ...

# %%
df['profit']=df['gross']-df['budget']

# %%
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                     723       178
# 1     Color     Gore Verbinski                     302       169
# 2     Color         Sam Mendes                     602       148
# 3     Color  Christopher Nolan                     813       164
# 5     Color     Andrew Stanton                     462       132
# ...     ...                ...                     ...       ...
# 5026  Color    Olivier Assayas                      81       110
# 5027  Color       Jafar Panahi                      64        90
# 5033  Color      Shane Carruth                     143        77
# 5035  Color   Robert Rodriguez                      56        81
# 5042  Color           Jon Gunn                      43        90
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                           0                     855   Joel David Moore
# ...

# %%
df.sort_values(by='profit', ascending=False, inplace=True)
df
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 0     Color     James Cameron                     723       178
# 29    Color   Colin Trevorrow                     644       124
# 26    Color     James Cameron                     315       194
# 3024  Color      George Lucas                     282       125
# 3080  Color  Steven Spielberg                     215       120
# ...     ...               ...                     ...       ...
# 2334  Color   Katsuhiro Ôtomo                     105       103
# 2323  Color    Hayao Miyazaki                     174       134
# 2988  Color      Joon-ho Bong                     363       110
# 3859  Color    Chan-wook Park                     202       112
# 3005  Color      Lajos Koltai                      73       134
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                           0                     855    Joel David Moore
# ...

# %%
df.tail(5)
# Out:
#       color    director_name  num_critic_for_reviews  duration  \
# 2334  Color  Katsuhiro Ôtomo                     105       103
# 2323  Color   Hayao Miyazaki                     174       134
# 2988  Color     Joon-ho Bong                     363       110
# 3859  Color   Chan-wook Park                     202       112
# 3005  Color     Lajos Koltai                      73       134
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 2334                       78                     101  Robin Atkin Downes
# 2323                     6000                     745  Jada Pinkett Smith
# 2988                      584                      74        Kang-ho Song
# 3859                        0                      38        Yeong-ae Lee
# 3005                       45                       0     Péter Fancsikai
#
#       actor_1_facebook_likes    gross  \
# 2334                     488   410388
# 2323                     893  2298191
# ...

# %%
df.sort_values(by='profit', ascending=False, inplace=True)
df.head(3)
# Out:
#     color    director_name  num_critic_for_reviews  duration  \
# 0   Color    James Cameron                     723       178
# 29  Color  Colin Trevorrow                     644       124
# 26  Color    James Cameron                     315       194
#
#     director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0                     855  Joel David Moore
# 29                      365                    1000        Judy Greer
# 26                        0                     794      Kate Winslet
#
#     actor_1_facebook_likes      gross                            genres  ...  \
# 0                     1000  760505847   Action|Adventure|Fantasy|Sci-Fi  ...
# 29                    3000  652177271  Action|Adventure|Sci-Fi|Thriller  ...
# 26                   29000  658672302                     Drama|Romance  ...
#
#    language country  content_rating     budget title_year  \
# 0   English     USA           PG-13  237000000       2009
# ...

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'profit'],
#       dtype='object')

# %%
df['genres'].unique
# Out:
# <bound method Series.unique of 0                         Action|Adventure|Fantasy|Sci-Fi
# 29                       Action|Adventure|Sci-Fi|Thriller
# 26                                          Drama|Romance
# 3024                      Action|Adventure|Fantasy|Sci-Fi
# 3080                                        Family|Sci-Fi
#                               ...
# 2334    Action|Adventure|Animation|Family|Sci-Fi|Thriller
# 2323                          Adventure|Animation|Fantasy
# 2988                           Comedy|Drama|Horror|Sci-Fi
# 3859                                          Crime|Drama
# 3005                                    Drama|Romance|War
# Name: genres, Length: 3755, dtype: object>

# %%
df['genres']=df['genres'].str.split('|')

# %%
df['title_year'] = pd.to_datetime(df['title_year'], format='%Y', errors='coerce')

# %%
df.to_excel(r"D:\Ind\projects\Career fair project\imdb_ipynb.xlsx", index=False)
